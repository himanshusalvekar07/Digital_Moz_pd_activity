# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#         ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 0      708746      17-08-2017    17-08-2017         916         103916  30-34
# 1      708749      17-08-2017    17-08-2017         916         103917  30-34
# 2      708771      17-08-2017    17-08-2017         916         103920  30-34
# 3      708815      30-08-2017    30-08-2017         916         103928  30-34
# 4      708818      17-08-2017    17-08-2017         916         103928  30-34
# ...       ...             ...           ...         ...            ...    ...
# 1138  1314410      19-08-2017    19-08-2017       45-49              F    109
# 1139  1314411      19-08-2017    19-08-2017       45-49              F    110
# 1140  1314412      19-08-2017    19-08-2017       45-49              F    111
# 1141  1314414      17-08-2017    17-08-2017       45-49              F    113
# 1142  1314415      17-08-2017    17-08-2017       45-49              F    114
#
# ...

# %%
df[df['age']=='30-34']['impressions'].sum()
# Out:
# 35678593.0

# %%
df[df['age']=='30-34']
# Out:
#        ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 0     708746      17-08-2017    17-08-2017         916         103916  30-34
# 1     708749      17-08-2017    17-08-2017         916         103917  30-34
# 2     708771      17-08-2017    17-08-2017         916         103920  30-34
# 3     708815      30-08-2017    30-08-2017         916         103928  30-34
# 4     708818      17-08-2017    17-08-2017         916         103928  30-34
# ..       ...             ...           ...         ...            ...    ...
# 615  1121282      24-08-2017    24-08-2017        1178         144570  30-34
# 616  1121284      24-08-2017    24-08-2017        1178         144571  30-34
# 617  1121285      24-08-2017    24-08-2017        1178         144571  30-34
# 618  1121286      24-08-2017    24-08-2017        1178         144571  30-34
# 619  1121287      24-08-2017    24-08-2017        1178         144571  30-34
#
# ...

# %%
pd.crosstab(df['ad_id'],df['campaign_id'])
# Out:
# campaign_id  1178  30-34  35-39  40-44  45-49  916  936
# ad_id
# 708746          0      0      0      0      0    1    0
# 708749          0      0      0      0      0    1    0
# 708771          0      0      0      0      0    1    0
# 708815          0      0      0      0      0    1    0
# 708818          0      0      0      0      0    1    0
# ...           ...    ...    ...    ...    ...  ...  ...
# 1314410         0      0      0      0      1    0    0
# 1314411         0      0      0      0      1    0    0
# 1314412         0      0      0      0      1    0    0
# 1314414         0      0      0      0      1    0    0
# 1314415         0      0      0      0      1    0    0
#
# [1143 rows x 7 columns]

# %%
df1=df['ad_id']

# %%
df1
# Out:
# 0        708746
# 1        708749
# 2        708771
# 3        708815
# 4        708818
#          ...
# 1138    1314410
# 1139    1314411
# 1140    1314412
# 1141    1314414
# 1142    1314415
# Name: ad_id, Length: 1143, dtype: int64
